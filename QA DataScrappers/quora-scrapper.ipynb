# %%
import urllib
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.quora.com/Should-I-move-to-London'

# %%
page = requests.get(url).text

# %%
page
# Out:
# '<!DOCTYPE html><html lang=\'en\' dir=\'ltr\' style=\'padding: 0; margin: 0;\'><head><meta http-equiv=\'Content-Type\' content=\'text/html; charset=utf-8\' /><link rel=\'icon\' href=\'https://qsf.fs.quoracdn.net/-4-images.favicon.ico-26-ebf6a9e7f7b4576d.ico\' /><title>Should I move to London? - Quora</title><meta name="robots" content="noarchive" /><meta name=\'twitter:widgets:theme\' content=\'light\' /><meta name=\'description\' content=\'I see a very simple solution to your situation however I notice it might not be what you want to hear - DTMFA. The fact you are asking us about moving to London alone tells me that this may be something you truly want. You have mentioned a number...\' /><link rel=\'canonical\' href=\'https://www.quora.com/Should-I-move-to-London\' /><script type="text/javascript" id="webpackNonceHack">window.nonce = "94ae72ee27cb40079b2914cea82b4a63";</script><link as=\'script\' rel=\'preload\' href=\'https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-27-c61d66ddc0
# ...

# %%
soup = BeautifulSoup(page, 'html.parser')

# %%
df = pd.DataFrame({'question': [],'answers':[]})

# %%
question = soup.find('script',atts={'type':'application/ld+json'})
answers = soup.find_all('div', attrs={'class': 'q-text'})

# %%
print(question)
# Out:
# None

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.quora.com/Should-I-move-to-London"
  
# Fetch raw HTML content
html_content = requests.get(url).text
  
# Now that the content is ready, iterate 
# through the content using BeautifulSoup:
soup = BeautifulSoup(html_content, "html.parser")
  
# similarly to get all the occurences of a given tag
print(soup.find('div').text)
# Out:
# Something went wrong. Wait a moment and try again.Try again
